# %%
import pandas as pd 

df = pd.read_csv("examples.csv")
df
# Out:
#        Country       Date  Total Booster
# 0   Afganistan  1/26/2021            1.0
# 1   Afganistan  1/27/2021            NaN
# 2   Afganistan  1/28/2021            5.0
# 3   Afganistan  1/29/2021            8.0
# 4   Afganistan  1/30/2021            9.0
# 5      Alzeria  1/26/2021           15.0
# 6      Alzeria  1/27/2021           17.0
# 7      Alzeria  1/28/2021            NaN
# 8      Alzeria  1/29/2021            NaN
# 9      Alzeria  1/30/2021            NaN
# 10     Alzeria  1/31/2021           55.0
# 11     Alzeria   2/1/2021           69.0
# 12     Alzeria   2/2/2021           20.0
# 13     Alzeria   2/3/2021            NaN
# 14     Alzeria   2/4/2021            NaN
# 15     Alzeria   2/5/2021           53.0
# 16     Alzeria   2/6/2021           23.0
# 17     Alzeria   2/7/2021           55.0
# 18     Alzeria   2/8/2021           44.0

# %%
df["Total Booster"] = df["Total Booster"].fillna(df["Total Booster"].shift(1))
df
# Out:
#        Country       Date  Total Booster
# 0   Afganistan  1/26/2021            1.0
# 1   Afganistan  1/27/2021            1.0
# 2   Afganistan  1/28/2021            5.0
# 3   Afganistan  1/29/2021            8.0
# 4   Afganistan  1/30/2021            9.0
# 5      Alzeria  1/26/2021           15.0
# 6      Alzeria  1/27/2021           17.0
# 7      Alzeria  1/28/2021           17.0
# 8      Alzeria  1/29/2021            NaN
# 9      Alzeria  1/30/2021            NaN
# 10     Alzeria  1/31/2021           55.0
# 11     Alzeria   2/1/2021           69.0
# 12     Alzeria   2/2/2021           20.0
# 13     Alzeria   2/3/2021           20.0
# 14     Alzeria   2/4/2021            NaN
# 15     Alzeria   2/5/2021           53.0
# 16     Alzeria   2/6/2021           23.0
# 17     Alzeria   2/7/2021           55.0
# 18     Alzeria   2/8/2021           44.0

# %%
def RevCS(x):
    x = x.fillna(df["Total Booster"].shift(1))
    x= x.diff().fillna(x.iloc[0])
    return x

df["new"] = RevCS(df["Total Booster"])
df
    
# df["Total Booster"] = df["Total Booster"].fillna(df["Total Booster"].shift(1))

# df["Booster"]= df["Total Booster"].diff().fillna(df['Total Booster'].iloc[0])
# df
# Out:
#        Country       Date  Total Booster   new
# 0   Afganistan  1/26/2021            1.0   1.0
# 1   Afganistan  1/27/2021            1.0   0.0
# 2   Afganistan  1/28/2021            5.0   4.0
# 3   Afganistan  1/29/2021            8.0   3.0
# 4   Afganistan  1/30/2021            9.0   1.0
# 5      Alzeria  1/26/2021           15.0   6.0
# 6      Alzeria  1/27/2021           17.0   2.0
# 7      Alzeria  1/28/2021           17.0   0.0
# 8      Alzeria  1/29/2021            NaN   0.0
# 9      Alzeria  1/30/2021            NaN   1.0
# 10     Alzeria  1/31/2021           55.0   1.0
# 11     Alzeria   2/1/2021           69.0  14.0
# 12     Alzeria   2/2/2021           20.0 -49.0
# 13     Alzeria   2/3/2021           20.0   0.0
# 14     Alzeria   2/4/2021            NaN   0.0
# 15     Alzeria   2/5/2021           53.0  33.0
# 16     Alzeria   2/6/2021           23.0 -30.0
# 17     Alzeria   2/7/2021           55.0  32.0
# 18     Alzeria   2/8/2021           44.0 -11.0

# %%
import pandas as pd 

df = pd.read_csv("Example.csv")
df
# Out:
#        total_boosters
# 0               28870
# 1               32750
# 2               71510
# 3               71510
# 4              124228
# ...               ...
# 32627          988856
# 32628          997670
# 32629         1003248
# 32630         1009486
# 32631         1014481
#
# [32632 rows x 1 columns]

# %%
import numpy as np
def RevCS(x):
    if x.shift(1) != np.nan :
        x = x.fillna(x.shift(1))
    else :
        x = x
    x= x.diff().fillna(x.iloc[0])
    return x

# %%
RevCS(df["total_boosters"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 RevCS(df["total_boosters"])
#
# Input In [42], in RevCS(x)
#       2 def RevCS(x):
# ----> 3     if x.shift(1) != np.nan :
#       4         x = x.fillna(x.shift(1))
#       5     else :
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['new'] = np.where(df["total_boosters"] != 'np.nan, df["total_boosters"].fillna(x.shift(1)), df["total_boosters"])
# Out:
#   Input In [48]
#     df['new'] = np.where(df["total_boosters"] != 'np.nan, df["total_boosters"].fillna(x.shift(1)), df["total_boosters"])
#                                                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df['new'] = df["total_boosters"].apply(lambda x: x.fillna(x.shift(1)) if x.shift(1) != np.nan else x )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 df['new'] = df["total_boosters"].apply(lambda x: x.fillna(x.shift(1)) if x.shift(1) != np.nan else x )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
# ...
